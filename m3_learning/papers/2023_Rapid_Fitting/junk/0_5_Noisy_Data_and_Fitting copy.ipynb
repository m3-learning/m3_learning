# %% [markdown]
# # 0.5 Generate Noisy Data and Fitting
#
# This notebook is used to generate and fit all the data required for the paper. We will generate data for the following noise cases:
#
# 1, 2, 3, 4, 5, 6, 7 STD

# %% [markdown]
# ## Imports

# %%
import sys

sys.path.append("../../")
sys.path.append("/home/ferroelectric/m3_learning/m3_learning/src")

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from m3_learning.be.dataset import BE_Dataset
from m3_learning.viz.printing import printer
from m3_learning.be.nn import SHO_fit_func_nn, SHO_Model
# Out:
# 2023-08-02 11:27:35.667622: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-02 11:27:35.785587: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-08-02 11:27:36.154899: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-08-02 11:27:36.154944: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-08-02 11:27:36.154949: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Loads the Dataset

# %%
# Specify the filename and the path to save the file
filename = "data_raw_SHO_try2.h5"
save_path = "./Data"

data_path = save_path + "/" + filename

# instantiate the dataset object
dataset = BE_Dataset(data_path, resample_bins=None, SHO_fit_func_NN=SHO_fit_func_nn)

# print the contents of the file
dataset.print_be_tree()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 data_path = save_path + "/" + filename
#       7 # instantiate the dataset object
# ----> 8 dataset = BE_Dataset(data_path, resample_bins=None, SHO_fit_func_NN=SHO_fit_func_nn)
#      10 # print the contents of the file
#      11 dataset.print_be_tree()
#
# File ~/m3_learning/m3_learning/src/m3_learning/be/dataset.py:94, in BE_Dataset.__init__(self, file_, scaled, raw_format, fitter, output_shape, measurement_state, resampled, resampled_bins, LSQF_phase_shift, NN_phase_shift, verbose, noise, basegroup, SHO_fit_func_LSQF, hysteresis_function, **kwargs)
#      92 # if None assigns it to the length of the original data
#      93 if resampled_bins is None:
# ---> 94     resampled_bins = self.num_bins
#      96 self.resampled_bins = resampled_bins
#      98 self.LSQF_phase_shift = LSQF_phase_shift
#
# File ~/m3_learning/m3_learning/src/m3_learning/be/dataset.py:444, in BE_Dataset.num_bins(self)
#     441 @property
#     442 def num_bins(self):
#     443     """Number of frequency bins in the data"""
# --> 444     with h5py.File(self.file, "r+") as h5_f:
#     445         return h5_f["Measurement_000"].attrs["num_bins"]
#
# File ~/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/h5py/_hl/files.py:533, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, **kwds)
#     525     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     526                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     527                      alignment_threshold=alignment_threshold,
#     528                      alignment_interval=alignment_interval,
#     529                      **kwds)
#     530     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     531                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     532                      fs_page_size=fs_page_size)
# --> 533     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     535 if isinstance(libver, tuple):
#     536     self._libver = libver
#
# File ~/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/h5py/_hl/files.py:228, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     226     fid = h5f.open(name, flags, fapl=fapl)
#     227 elif mode == 'r+':
# --> 228     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     229 elif mode in ['w-', 'x']:
#     230     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = './Data/data_raw_SHO_try2.h5', errno = 2, error message = 'No such file or directory', flags = 1, o_flags = 2)

# %% [markdown]
# ## Generates Noisy Data
#
# This function will generate noisy records and save them as an h5_main file in the USID format. This allows the data to be computed with the Pycroscopy SHO Fitter.

# %%
noise_STD = np.std(dataset.get_original_data)

# %%
print(noise_STD)
# Out:
# 0.0038833667

# %%
dataset.generate_noisy_data_records(noise_levels = np.arange(1,9), verbose=True, noise_STD=noise_STD)
# Out:
# The STD of the data is: 0.0038833667058497667
# Adding noise level 1
# Adding noise level 2
# Adding noise level 3
# Adding noise level 4
# Adding noise level 5
# Adding noise level 6
# Adding noise level 7
# Adding noise level 8

# %% [markdown]
# ## SHO fits on all the datasets
#
# This will take some time, Each fit takes about 10 minutes to complete.

# %%
out = [f"Noisy_Data_{i}" for i in np.arange(1,9)]
out.append("Raw_Data")

for data in out:
    print(f"Fitting {data}")
    dataset.SHO_Fitter(dataset = data, h5_sho_targ_grp = f"{data}_SHO_Fit", max_mem=1024*64, max_cores= 20)
# Out:
# Fitting Noisy_Data_1
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.04 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.94 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.86 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.78 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.68 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.61 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.52 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.43 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.35 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.26 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 1.0 mins
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 54.34 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 49.1 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 43.78 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 38.45 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 33.41 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 28.73 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 23.81 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 18.85 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 13.82 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.67 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.6 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 5.06 mins
# Rank 0 - 6% complete. Time remaining: 3.94 mins
# Rank 0 - 10% complete. Time remaining: 3.33 mins
# Rank 0 - 13% complete. Time remaining: 2.97 mins
# Rank 0 - 16% complete. Time remaining: 2.7 mins
# Rank 0 - 20% complete. Time remaining: 2.2 mins
# Rank 0 - 23% complete. Time remaining: 2.02 mins
# Rank 0 - 26% complete. Time remaining: 1.92 mins
# Rank 0 - 30% complete. Time remaining: 1.84 mins
# Rank 0 - 33% complete. Time remaining: 1.82 mins
# Rank 0 - 36% complete. Time remaining: 1.7 mins
# Rank 0 - 40% complete. Time remaining: 1.62 mins
# Rank 0 - 43% complete. Time remaining: 1.52 mins
# Rank 0 - 46% complete. Time remaining: 1.43 mins
# Rank 0 - 50% complete. Time remaining: 1.31 mins
# Rank 0 - 53% complete. Time remaining: 1.23 mins
# Rank 0 - 56% complete. Time remaining: 1.18 mins
# Rank 0 - 60% complete. Time remaining: 1.08 mins
# Rank 0 - 63% complete. Time remaining: 1.0 mins
# Rank 0 - 66% complete. Time remaining: 53.96 sec
# Rank 0 - 70% complete. Time remaining: 48.24 sec
# Rank 0 - 73% complete. Time remaining: 41.2 sec
# Rank 0 - 76% complete. Time remaining: 36.99 sec
# Rank 0 - 80% complete. Time remaining: 31.7 sec
# Rank 0 - 83% complete. Time remaining: 26.4 sec
# Rank 0 - 86% complete. Time remaining: 21.94 sec
# Rank 0 - 90% complete. Time remaining: 16.33 sec
# Rank 0 - 93% complete. Time remaining: 10.81 sec
# Rank 0 - 96% complete. Time remaining: 5.33 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 333.25208139419556 seconds to compute parameters
# Fitting Noisy_Data_2
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.07 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.04 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.98 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.9 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.81 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.73 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.65 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.56 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.46 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.38 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.29 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.19 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.11 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 1.03 mins
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 56.55 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 51.37 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 46.08 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 40.81 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 35.44 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 30.23 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 24.92 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 19.63 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 14.24 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 9.02 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.73 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.71 mins
# Rank 0 - 6% complete. Time remaining: 2.52 mins
# Rank 0 - 10% complete. Time remaining: 2.56 mins
# Rank 0 - 13% complete. Time remaining: 2.41 mins
# Rank 0 - 16% complete. Time remaining: 2.3 mins
# Rank 0 - 20% complete. Time remaining: 2.26 mins
# Rank 0 - 23% complete. Time remaining: 2.17 mins
# Rank 0 - 26% complete. Time remaining: 2.0 mins
# Rank 0 - 30% complete. Time remaining: 1.93 mins
# Rank 0 - 33% complete. Time remaining: 1.85 mins
# Rank 0 - 36% complete. Time remaining: 1.69 mins
# Rank 0 - 40% complete. Time remaining: 1.66 mins
# Rank 0 - 43% complete. Time remaining: 1.59 mins
# Rank 0 - 46% complete. Time remaining: 1.49 mins
# Rank 0 - 50% complete. Time remaining: 1.39 mins
# Rank 0 - 53% complete. Time remaining: 1.34 mins
# Rank 0 - 56% complete. Time remaining: 1.2 mins
# Rank 0 - 60% complete. Time remaining: 1.08 mins
# Rank 0 - 63% complete. Time remaining: 59.8 sec
# Rank 0 - 66% complete. Time remaining: 53.38 sec
# Rank 0 - 70% complete. Time remaining: 48.56 sec
# Rank 0 - 73% complete. Time remaining: 44.9 sec
# Rank 0 - 76% complete. Time remaining: 40.91 sec
# Rank 0 - 80% complete. Time remaining: 34.9 sec
# Rank 0 - 83% complete. Time remaining: 29.05 sec
# Rank 0 - 86% complete. Time remaining: 23.06 sec
# Rank 0 - 90% complete. Time remaining: 16.71 sec
# Rank 0 - 93% complete. Time remaining: 10.79 sec
# Rank 0 - 96% complete. Time remaining: 5.41 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 338.72926092147827 seconds to compute parameters
# Fitting Noisy_Data_3
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.2 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 2.0 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.91 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.82 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.72 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.64 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.56 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.46 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.38 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.3 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.21 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.12 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 1.04 mins
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 57.04 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 52.03 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 46.66 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 41.09 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 35.65 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 30.48 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 25.19 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 19.83 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 14.55 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 9.18 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.79 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.66 mins
# Rank 0 - 6% complete. Time remaining: 2.47 mins
# Rank 0 - 10% complete. Time remaining: 2.43 mins
# Rank 0 - 13% complete. Time remaining: 2.35 mins
# Rank 0 - 16% complete. Time remaining: 2.31 mins
# Rank 0 - 20% complete. Time remaining: 2.2 mins
# Rank 0 - 23% complete. Time remaining: 2.14 mins
# Rank 0 - 26% complete. Time remaining: 2.04 mins
# Rank 0 - 30% complete. Time remaining: 1.9 mins
# Rank 0 - 33% complete. Time remaining: 1.75 mins
# Rank 0 - 36% complete. Time remaining: 1.69 mins
# Rank 0 - 40% complete. Time remaining: 1.59 mins
# Rank 0 - 43% complete. Time remaining: 1.53 mins
# Rank 0 - 46% complete. Time remaining: 1.47 mins
# Rank 0 - 50% complete. Time remaining: 1.39 mins
# Rank 0 - 53% complete. Time remaining: 1.27 mins
# Rank 0 - 56% complete. Time remaining: 1.19 mins
# Rank 0 - 60% complete. Time remaining: 1.1 mins
# Rank 0 - 63% complete. Time remaining: 1.04 mins
# Rank 0 - 66% complete. Time remaining: 57.44 sec
# Rank 0 - 70% complete. Time remaining: 51.77 sec
# Rank 0 - 73% complete. Time remaining: 45.54 sec
# Rank 0 - 76% complete. Time remaining: 39.3 sec
# Rank 0 - 80% complete. Time remaining: 31.99 sec
# Rank 0 - 83% complete. Time remaining: 26.61 sec
# Rank 0 - 86% complete. Time remaining: 21.62 sec
# Rank 0 - 90% complete. Time remaining: 16.05 sec
# Rank 0 - 93% complete. Time remaining: 10.61 sec
# Rank 0 - 96% complete. Time remaining: 5.38 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 337.12325525283813 seconds to compute parameters
# Fitting Noisy_Data_4
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.01 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 1.97 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 1.89 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.8 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.73 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.66 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.56 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.48 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.39 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.31 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.23 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.15 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.07 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 58.9 sec
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 53.72 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 48.73 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 43.57 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 38.71 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 33.96 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 29.19 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 23.93 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 18.94 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 13.78 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 8.66 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.6 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.65 mins
# Rank 0 - 6% complete. Time remaining: 2.52 mins
# Rank 0 - 10% complete. Time remaining: 2.61 mins
# Rank 0 - 13% complete. Time remaining: 2.43 mins
# Rank 0 - 16% complete. Time remaining: 2.39 mins
# Rank 0 - 20% complete. Time remaining: 2.29 mins
# Rank 0 - 23% complete. Time remaining: 2.22 mins
# Rank 0 - 26% complete. Time remaining: 2.01 mins
# Rank 0 - 30% complete. Time remaining: 1.93 mins
# Rank 0 - 33% complete. Time remaining: 1.77 mins
# Rank 0 - 36% complete. Time remaining: 1.69 mins
# Rank 0 - 40% complete. Time remaining: 1.63 mins
# Rank 0 - 43% complete. Time remaining: 1.6 mins
# Rank 0 - 46% complete. Time remaining: 1.51 mins
# Rank 0 - 50% complete. Time remaining: 1.42 mins
# Rank 0 - 53% complete. Time remaining: 1.3 mins
# Rank 0 - 56% complete. Time remaining: 1.18 mins
# Rank 0 - 60% complete. Time remaining: 1.07 mins
# Rank 0 - 63% complete. Time remaining: 58.43 sec
# Rank 0 - 66% complete. Time remaining: 53.56 sec
# Rank 0 - 70% complete. Time remaining: 48.33 sec
# Rank 0 - 73% complete. Time remaining: 43.57 sec
# Rank 0 - 76% complete. Time remaining: 37.59 sec
# Rank 0 - 80% complete. Time remaining: 32.22 sec
# Rank 0 - 83% complete. Time remaining: 27.44 sec
# Rank 0 - 86% complete. Time remaining: 22.71 sec
# Rank 0 - 90% complete. Time remaining: 16.76 sec
# Rank 0 - 93% complete. Time remaining: 11.56 sec
# Rank 0 - 96% complete. Time remaining: 5.86 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 334.2028138637543 seconds to compute parameters
# Fitting Noisy_Data_5
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.17 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 2.01 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.92 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.84 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.76 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.66 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.58 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.49 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.4 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.31 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.23 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.14 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 1.05 mins
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 57.77 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 52.15 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 46.83 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 41.52 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 35.95 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 30.53 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 25.19 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 19.85 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 14.38 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 9.15 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.79 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.76 mins
# Rank 0 - 6% complete. Time remaining: 2.56 mins
# Rank 0 - 10% complete. Time remaining: 2.43 mins
# Rank 0 - 13% complete. Time remaining: 2.35 mins
# Rank 0 - 16% complete. Time remaining: 2.25 mins
# Rank 0 - 20% complete. Time remaining: 2.11 mins
# Rank 0 - 23% complete. Time remaining: 2.01 mins
# Rank 0 - 26% complete. Time remaining: 1.97 mins
# Rank 0 - 30% complete. Time remaining: 1.86 mins
# Rank 0 - 33% complete. Time remaining: 1.83 mins
# Rank 0 - 36% complete. Time remaining: 1.77 mins
# Rank 0 - 40% complete. Time remaining: 1.68 mins
# Rank 0 - 43% complete. Time remaining: 1.54 mins
# Rank 0 - 46% complete. Time remaining: 1.47 mins
# Rank 0 - 50% complete. Time remaining: 1.33 mins
# Rank 0 - 53% complete. Time remaining: 1.27 mins
# Rank 0 - 56% complete. Time remaining: 1.2 mins
# Rank 0 - 60% complete. Time remaining: 1.15 mins
# Rank 0 - 63% complete. Time remaining: 1.05 mins
# Rank 0 - 66% complete. Time remaining: 59.34 sec
# Rank 0 - 70% complete. Time remaining: 53.75 sec
# Rank 0 - 73% complete. Time remaining: 47.5 sec
# Rank 0 - 76% complete. Time remaining: 41.31 sec
# Rank 0 - 80% complete. Time remaining: 35.44 sec
# Rank 0 - 83% complete. Time remaining: 29.63 sec
# Rank 0 - 86% complete. Time remaining: 23.53 sec
# Rank 0 - 90% complete. Time remaining: 18.31 sec
# Rank 0 - 93% complete. Time remaining: 11.97 sec
# Rank 0 - 96% complete. Time remaining: 6.04 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 343.6695046424866 seconds to compute parameters
# Fitting Noisy_Data_6
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.19 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.1 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 2.03 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.96 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.86 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.79 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.7 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.6 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.5 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.41 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.31 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.21 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.12 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 1.03 mins
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 55.99 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 50.83 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 45.51 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 40.3 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 34.85 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 30.07 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 24.89 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 19.75 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 14.41 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 9.13 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.75 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.68 mins
# Rank 0 - 6% complete. Time remaining: 2.47 mins
# Rank 0 - 10% complete. Time remaining: 2.45 mins
# Rank 0 - 13% complete. Time remaining: 2.34 mins
# Rank 0 - 16% complete. Time remaining: 2.26 mins
# Rank 0 - 20% complete. Time remaining: 2.15 mins
# Rank 0 - 23% complete. Time remaining: 2.05 mins
# Rank 0 - 26% complete. Time remaining: 1.94 mins
# Rank 0 - 30% complete. Time remaining: 1.93 mins
# Rank 0 - 33% complete. Time remaining: 1.85 mins
# Rank 0 - 36% complete. Time remaining: 1.76 mins
# Rank 0 - 40% complete. Time remaining: 1.75 mins
# Rank 0 - 43% complete. Time remaining: 1.64 mins
# Rank 0 - 46% complete. Time remaining: 1.55 mins
# Rank 0 - 50% complete. Time remaining: 1.49 mins
# Rank 0 - 53% complete. Time remaining: 1.38 mins
# Rank 0 - 56% complete. Time remaining: 1.29 mins
# Rank 0 - 60% complete. Time remaining: 1.19 mins
# Rank 0 - 63% complete. Time remaining: 1.09 mins
# Rank 0 - 66% complete. Time remaining: 59.46 sec
# Rank 0 - 70% complete. Time remaining: 53.59 sec
# Rank 0 - 73% complete. Time remaining: 46.98 sec
# Rank 0 - 76% complete. Time remaining: 41.59 sec
# Rank 0 - 80% complete. Time remaining: 34.27 sec
# Rank 0 - 83% complete. Time remaining: 27.09 sec
# Rank 0 - 86% complete. Time remaining: 22.06 sec
# Rank 0 - 90% complete. Time remaining: 16.59 sec
# Rank 0 - 93% complete. Time remaining: 11.0 sec
# Rank 0 - 96% complete. Time remaining: 5.68 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 344.4803636074066 seconds to compute parameters
# Fitting Noisy_Data_7
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.11 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 2.01 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.92 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.83 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.76 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.65 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.56 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.47 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.38 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.29 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.21 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.12 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 1.03 mins
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 56.72 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 51.41 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 46.33 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 41.06 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 35.83 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 30.46 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 25.0 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 19.63 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 14.3 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 9.05 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.77 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 3.01 mins
# Rank 0 - 6% complete. Time remaining: 2.89 mins
# Rank 0 - 10% complete. Time remaining: 2.78 mins
# Rank 0 - 13% complete. Time remaining: 2.59 mins
# Rank 0 - 16% complete. Time remaining: 2.45 mins
# Rank 0 - 20% complete. Time remaining: 2.26 mins
# Rank 0 - 23% complete. Time remaining: 2.07 mins
# Rank 0 - 26% complete. Time remaining: 1.92 mins
# Rank 0 - 30% complete. Time remaining: 1.81 mins
# Rank 0 - 33% complete. Time remaining: 1.77 mins
# Rank 0 - 36% complete. Time remaining: 1.7 mins
# Rank 0 - 40% complete. Time remaining: 1.66 mins
# Rank 0 - 43% complete. Time remaining: 1.53 mins
# Rank 0 - 46% complete. Time remaining: 1.49 mins
# Rank 0 - 50% complete. Time remaining: 1.36 mins
# Rank 0 - 53% complete. Time remaining: 1.26 mins
# Rank 0 - 56% complete. Time remaining: 1.16 mins
# Rank 0 - 60% complete. Time remaining: 1.11 mins
# Rank 0 - 63% complete. Time remaining: 59.33 sec
# Rank 0 - 66% complete. Time remaining: 55.66 sec
# Rank 0 - 70% complete. Time remaining: 51.1 sec
# Rank 0 - 73% complete. Time remaining: 46.94 sec
# Rank 0 - 76% complete. Time remaining: 40.14 sec
# Rank 0 - 80% complete. Time remaining: 35.38 sec
# Rank 0 - 83% complete. Time remaining: 28.28 sec
# Rank 0 - 86% complete. Time remaining: 22.2 sec
# Rank 0 - 90% complete. Time remaining: 15.86 sec
# Rank 0 - 93% complete. Time remaining: 10.66 sec
# Rank 0 - 96% complete. Time remaining: 5.21 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 339.1040589809418 seconds to compute parameters
# Fitting Noisy_Data_8
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 3% complete. Time remaining: 2.18 mins
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 2.09 mins
# Rank 0 finished parallel computation
# Rank 0 - 11% complete. Time remaining: 2.01 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.93 mins
# Rank 0 finished parallel computation
# Rank 0 - 19% complete. Time remaining: 1.84 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.75 mins
# Rank 0 finished parallel computation
# Rank 0 - 27% complete. Time remaining: 1.65 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.56 mins
# Rank 0 finished parallel computation
# Rank 0 - 35% complete. Time remaining: 1.46 mins
# Rank 0 finished parallel computation
# Rank 0 - 38% complete. Time remaining: 1.38 mins
# Rank 0 finished parallel computation
# Rank 0 - 42% complete. Time remaining: 1.28 mins
# Rank 0 finished parallel computation
# Rank 0 - 46% complete. Time remaining: 1.2 mins
# Rank 0 finished parallel computation
# Rank 0 - 50% complete. Time remaining: 1.11 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 1.03 mins
# Rank 0 finished parallel computation
# Rank 0 - 58% complete. Time remaining: 55.91 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 51.29 sec
# Rank 0 finished parallel computation
# Rank 0 - 66% complete. Time remaining: 45.45 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 40.44 sec
# Rank 0 finished parallel computation
# Rank 0 - 73% complete. Time remaining: 35.06 sec
# Rank 0 finished parallel computation
# Rank 0 - 77% complete. Time remaining: 30.0 sec
# Rank 0 finished parallel computation
# Rank 0 - 81% complete. Time remaining: 24.7 sec
# Rank 0 finished parallel computation
# Rank 0 - 85% complete. Time remaining: 19.58 sec
# Rank 0 finished parallel computation
# Rank 0 - 89% complete. Time remaining: 14.35 sec
# Rank 0 finished parallel computation
# Rank 0 - 93% complete. Time remaining: 9.11 sec
# Rank 0 finished parallel computation
# Rank 0 - 97% complete. Time remaining: 3.81 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000" (4 members)>]
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Rank 0 - 3% complete. Time remaining: 2.64 mins
# Rank 0 - 6% complete. Time remaining: 2.49 mins
# Rank 0 - 10% complete. Time remaining: 2.48 mins
# Rank 0 - 13% complete. Time remaining: 2.37 mins
# Rank 0 - 16% complete. Time remaining: 2.27 mins
# Rank 0 - 20% complete. Time remaining: 2.23 mins
# Rank 0 - 23% complete. Time remaining: 2.2 mins
# Rank 0 - 26% complete. Time remaining: 2.07 mins
# Rank 0 - 30% complete. Time remaining: 1.97 mins
# Rank 0 - 33% complete. Time remaining: 1.95 mins
# Rank 0 - 36% complete. Time remaining: 1.82 mins
# Rank 0 - 40% complete. Time remaining: 1.72 mins
# Rank 0 - 43% complete. Time remaining: 1.63 mins
# Rank 0 - 46% complete. Time remaining: 1.53 mins
# Rank 0 - 50% complete. Time remaining: 1.36 mins
# Rank 0 - 53% complete. Time remaining: 1.27 mins
# Rank 0 - 56% complete. Time remaining: 1.16 mins
# Rank 0 - 60% complete. Time remaining: 1.11 mins
# Rank 0 - 63% complete. Time remaining: 1.05 mins
# Rank 0 - 66% complete. Time remaining: 59.48 sec
# Rank 0 - 70% complete. Time remaining: 54.25 sec
# Rank 0 - 73% complete. Time remaining: 49.15 sec
# Rank 0 - 76% complete. Time remaining: 42.27 sec
# Rank 0 - 80% complete. Time remaining: 35.4 sec
# Rank 0 - 83% complete. Time remaining: 28.84 sec
# Rank 0 - 86% complete. Time remaining: 22.68 sec
# Rank 0 - 90% complete. Time remaining: 16.49 sec
# Rank 0 - 93% complete. Time remaining: 11.02 sec
# Rank 0 - 96% complete. Time remaining: 5.41 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 342.1938257217407 seconds to compute parameters
# Fitting Raw_Data
# Working on:
# ./Data/data_raw_SHO.h5
# ['Y', 'X'] [60, 60]
#
#
# SHO Fits will be written to:
# ./Data/data_raw_SHO.h5
#
#
# Consider calling test() to check results before calling compute() which computes on the entire dataset and writes results to the HDF5 file
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 finished parallel computation
# Rank 0 - 7% complete. Time remaining: 1.99 mins
# Rank 0 finished parallel computation
# Rank 0 - 15% complete. Time remaining: 1.83 mins
# Rank 0 finished parallel computation
# Rank 0 - 23% complete. Time remaining: 1.65 mins
# Rank 0 finished parallel computation
# Rank 0 - 31% complete. Time remaining: 1.48 mins
# Rank 0 finished parallel computation
# Rank 0 - 39% complete. Time remaining: 1.31 mins
# Rank 0 finished parallel computation
# Rank 0 - 47% complete. Time remaining: 1.14 mins
# Rank 0 finished parallel computation
# Rank 0 - 54% complete. Time remaining: 58.24 sec
# Rank 0 finished parallel computation
# Rank 0 - 62% complete. Time remaining: 48.16 sec
# Rank 0 finished parallel computation
# Rank 0 - 70% complete. Time remaining: 37.79 sec
# Rank 0 finished parallel computation
# Rank 0 - 78% complete. Time remaining: 27.59 sec
# Rank 0 finished parallel computation
# Rank 0 - 86% complete. Time remaining: 17.6 sec
# Rank 0 finished parallel computation
# Rank 0 - 94% complete. Time remaining: 7.63 sec
# Rank 0 finished parallel computation
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
#
# Note: SHO_Fit has already been performed with the same parameters before. These results will be returned by compute() by default. Set override to True to force fresh computation
#
# [<HDF5 group "/Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000" (4 members)>]
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# /home/ferroelectric/anaconda3/envs/rapidfitting/lib/python3.9/site-packages/BGlib/be/analysis/fitter.py:140: UserWarning: status dataset not created yet
#   warn('status dataset not created yet')
# Resuming computation. 0% completed already
# 	This class (likely) supports interruption and resuming of computations!
# 	If you are operating in a python console, press Ctrl+C or Cmd+C to abort
# 	If you are in a Jupyter notebook, click on "Kernel">>"Interrupt"
# 	If you are operating on a cluster and your job gets killed, re-run the job to resume
#
# Rank 0 - 6% complete. Time remaining: 2.21 mins
# Rank 0 - 13% complete. Time remaining: 2.03 mins
# Rank 0 - 20% complete. Time remaining: 2.07 mins
# Rank 0 - 26% complete. Time remaining: 1.98 mins
# Rank 0 - 33% complete. Time remaining: 1.79 mins
# Rank 0 - 40% complete. Time remaining: 1.62 mins
# Rank 0 - 46% complete. Time remaining: 1.47 mins
# Rank 0 - 53% complete. Time remaining: 1.22 mins
# Rank 0 - 60% complete. Time remaining: 59.65 sec
# Rank 0 - 66% complete. Time remaining: 48.97 sec
# Rank 0 - 73% complete. Time remaining: 40.98 sec
# Rank 0 - 80% complete. Time remaining: 30.19 sec
# Rank 0 - 87% complete. Time remaining: 20.08 sec
# Rank 0 - 93% complete. Time remaining: 9.71 sec
# Rank 0 - 100% complete. Time remaining: 0.0 msec
# Finished processing the entire dataset!
# LSQF method took 305.63558411598206 seconds to compute parameters

# %% [markdown]
# ### Checks the results to make sure it was saved correctly

# %%
# print the contents of the file
dataset.print_be_tree()
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ Bin_FFT
#     ├ Bin_Frequencies
#     ├ Bin_Indices
#     ├ Bin_Step
#     ├ Bin_Wfm_Type
#     ├ Excitation_Waveform
#     ├ Noise_Floor
#     ├ Noisy_Data_1
#     ├ Noisy_Data_2
#     ├ Noisy_Data_3
#     ├ Noisy_Data_4
#     ├ Noisy_Data_5
#     ├ Noisy_Data_6
#     ├ Noisy_Data_7
#     ├ Noisy_Data_8
#     ├ Position_Indices
#     ├ Position_Values
#     ├ Raw_Data
#     ├ Spatially_Averaged_Plot_Group_000
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spatially_Averaged_Plot_Group_001
#       ---------------------------------
#       ├ Bin_Frequencies
#       ├ Max_Response
#       ├ Mean_Spectrogram
#       ├ Min_Response
#       ├ Spectroscopic_Parameter
#       ├ Step_Averaged_Response
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ UDVS
#     ├ UDVS_Indices
# ├ Noisy_Data_1_SHO_Fit
#   --------------------
#   ├ Noisy_Data_1-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_2_SHO_Fit
#   --------------------
#   ├ Noisy_Data_2-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_3_SHO_Fit
#   --------------------
#   ├ Noisy_Data_3-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_4_SHO_Fit
#   --------------------
#   ├ Noisy_Data_4-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_5_SHO_Fit
#   --------------------
#   ├ Noisy_Data_5-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_6_SHO_Fit
#   --------------------
#   ├ Noisy_Data_6-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_7_SHO_Fit
#   --------------------
#   ├ Noisy_Data_7-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Noisy_Data_8_SHO_Fit
#   --------------------
#   ├ Noisy_Data_8-SHO_Fit_000
#     ------------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# ├ Raw_Data_SHO_Fit
#   ----------------
#   ├ Raw_Data-SHO_Fit_000
#     --------------------
#     ├ Fit
#     ├ Guess
#     ├ Spectroscopic_Indices
#     ├ Spectroscopic_Values
#     ├ completed_fit_positions
#     ├ completed_guess_positions
# Datasets and datagroups within the file:
# ------------------------------------
# /
# /Measurement_000
# /Measurement_000/Channel_000
# /Measurement_000/Channel_000/Bin_FFT
# /Measurement_000/Channel_000/Bin_Frequencies
# /Measurement_000/Channel_000/Bin_Indices
# /Measurement_000/Channel_000/Bin_Step
# /Measurement_000/Channel_000/Bin_Wfm_Type
# /Measurement_000/Channel_000/Excitation_Waveform
# /Measurement_000/Channel_000/Noise_Floor
# /Measurement_000/Channel_000/Noisy_Data_1
# /Measurement_000/Channel_000/Noisy_Data_2
# /Measurement_000/Channel_000/Noisy_Data_3
# /Measurement_000/Channel_000/Noisy_Data_4
# /Measurement_000/Channel_000/Noisy_Data_5
# /Measurement_000/Channel_000/Noisy_Data_6
# /Measurement_000/Channel_000/Noisy_Data_7
# /Measurement_000/Channel_000/Noisy_Data_8
# /Measurement_000/Channel_000/Position_Indices
# /Measurement_000/Channel_000/Position_Values
# /Measurement_000/Channel_000/Raw_Data
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_000/Step_Averaged_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Bin_Frequencies
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Max_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Mean_Spectrogram
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Min_Response
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Spectroscopic_Parameter
# /Measurement_000/Channel_000/Spatially_Averaged_Plot_Group_001/Step_Averaged_Response
# /Measurement_000/Channel_000/Spectroscopic_Indices
# /Measurement_000/Channel_000/Spectroscopic_Values
# /Measurement_000/Channel_000/UDVS
# /Measurement_000/Channel_000/UDVS_Indices
# /Noisy_Data_1_SHO_Fit
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Fit
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Guess
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_1_SHO_Fit/Noisy_Data_1-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_2_SHO_Fit
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Fit
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Guess
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_2_SHO_Fit/Noisy_Data_2-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_3_SHO_Fit
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Fit
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Guess
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_3_SHO_Fit/Noisy_Data_3-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_4_SHO_Fit
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Fit
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Guess
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_4_SHO_Fit/Noisy_Data_4-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_5_SHO_Fit
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Fit
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Guess
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_5_SHO_Fit/Noisy_Data_5-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_6_SHO_Fit
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Fit
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Guess
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_6_SHO_Fit/Noisy_Data_6-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_7_SHO_Fit
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Fit
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Guess
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_7_SHO_Fit/Noisy_Data_7-SHO_Fit_000/completed_guess_positions
# /Noisy_Data_8_SHO_Fit
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Fit
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Guess
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Spectroscopic_Indices
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/Spectroscopic_Values
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/completed_fit_positions
# /Noisy_Data_8_SHO_Fit/Noisy_Data_8-SHO_Fit_000/completed_guess_positions
# /Raw_Data_SHO_Fit
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Fit
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Guess
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Spectroscopic_Indices
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/Spectroscopic_Values
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/completed_fit_positions
# /Raw_Data_SHO_Fit/Raw_Data-SHO_Fit_000/completed_guess_positions
#
# The main dataset:
# ------------------------------------
# <HDF5 file "data_raw_SHO.h5" (mode r+)>
#
# The ancillary datasets:
# ------------------------------------
# <HDF5 dataset "Position_Indices": shape (3600, 2), type "<u4">
# <HDF5 dataset "Position_Values": shape (3600, 2), type "<f4">
# <HDF5 dataset "Spectroscopic_Indices": shape (4, 63360), type "<u4">
# <HDF5 dataset "Spectroscopic_Values": shape (4, 63360), type "<f4">
#
# Metadata or attributes in a datagroup
# ------------------------------------
# BE_actual_duration_[s] : 0.004
# BE_amplitude_[V] : 1
# BE_auto_smoothing : auto smoothing on
# BE_band_edge_smoothing_[s] : 4832.1
# BE_band_edge_trim : 0.094742
# BE_band_width_[Hz] : 200000
# BE_bins_per_band : 0
# BE_center_frequency_[Hz] : 1310000
# BE_desired_duration_[s] : 0.004
# BE_phase_content : chirp-sinc hybrid
# BE_phase_variation : 1
# BE_points_per_BE_wave : 0
# BE_repeats : 4
# FORC_V_high1_[V] : 1
# FORC_V_high2_[V] : 10
# FORC_V_low1_[V] : -1
# FORC_V_low2_[V] : -10
# FORC_num_of_FORC_cycles : 1
# FORC_num_of_FORC_repeats : 1
# File_MDAQ_version : MDAQ_VS_090915_01
# File_date_and_time : 18-Sep-2015 18:32:14
# File_file_name : SP128_NSO
# File_file_path : C:\Users\Asylum User\Documents\Users\Agar\SP128_NSO\
# File_file_suffix : 99
# IO_AO_amplifier : 10
# IO_AO_range_[V] : +/- 10
# IO_Analog_Input_1 : +/- .1V, FFT
# IO_Analog_Input_2 : off
# IO_Analog_Input_3 : off
# IO_Analog_Input_4 : off
# IO_DAQ_platform : NI 6115
# IO_rate_[Hz] : 4000000
# VS_amplitude_[V] : 16
# VS_cycle_fraction : full
# VS_cycle_phase_shift : 0
# VS_measure_in_field_loops : in and out-of-field
# VS_mode : DC modulation mode
# VS_number_of_cycles : 2
# VS_offset_[V] : 0
# VS_read_voltage_[V] : 0
# VS_set_pulse_amplitude[V] : 0
# VS_set_pulse_duration[s] : 0.002
# VS_step_edge_smoothing_[s] : 0.001
# VS_steps_per_full_cycle : 96
# data_type : BEPSData
# grid_/single : grid
# grid_contact_set_point_[V] : 1
# grid_current_col : 1
# grid_current_row : 1
# grid_cycle_time_[s] : 10
# grid_measuring : 0
# grid_moving : 0
# grid_num_cols : 60
# grid_num_rows : 60
# grid_settle_time_[s] : 0.15
# grid_time_remaining_[h;m;s] : 10
# grid_total_time_[h;m;s] : 10
# grid_transit_set_point_[V] : 0.1
# grid_transit_time_[s] : 0.15
# num_bins : 165
# num_pix : 3600
# num_udvs_steps : 384
